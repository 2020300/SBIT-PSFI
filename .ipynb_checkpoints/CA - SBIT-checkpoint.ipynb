# %% [markdown]
# ### Python code used to analyse dataset
#
# #### https://www.kaggle.com/code/christinampoid/europe-habits

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
foodhabits = pd.read_csv('C:/Users/henri/Documents/GitHub/SBIT-PSFI/dataset modified.csv', delimiter=';')

# %%
foodhabits.describe()
# Out:
#          Code        product_name   Category Healthy / Unhealthy  \
# count    4562                4562       1599                 267
# unique   3009                4562        796                   2
# top     2E+12  Crema de guisantes  Chocolate             Healthy
# freq      315                   1        221                 256
#
#              countries countries_en
# count             4562         4562
# unique               2            2
# top     United Kingdom           UK
# freq              2691         2691

# %%
foodhabits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4562 entries, 0 to 4561
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Code                 4562 non-null   object
#  1   product_name         4562 non-null   object
#  2   Category             1599 non-null   object
#  3   Healthy / Unhealthy  267 non-null    object
#  4   countries            4562 non-null   object
#  5   countries_en         4562 non-null   object
# dtypes: object(6)
# memory usage: 214.0+ KB

# %%
foodhabits.tail(5)
# Out:
#              Code                                       product_name Category  \
# 4557  3,25622E+12  Chocolat lait fourré Praliné éclats de Noisett...      NaN
# 4558       902182                           Raisin Rouge Sans Pépins      NaN
# 4559  7,61004E+12                      Chocolat à boire à l'ancienne      NaN
# 4560  8,41074E+12   Tableta de chocolate negro con naranja 70% cacao      NaN
# 4561   8,7104E+12                                    Pickles Flavour      NaN
#
#      Healthy / Unhealthy       countries countries_en
# 4557                 NaN  United Kingdom           UK
# 4558                 NaN  United Kingdom           UK
# 4559                 NaN  United Kingdom           UK
# 4560                 NaN  United Kingdom           UK
# 4561                 NaN  United Kingdom           UK

# %%
foodhabits.head(100)
# Out:
#            Code                            product_name  \
# 0   8,41252E+12                      Crema de guisantes
# 1   7,61703E+12  De la région TOMME à l'arôme de TRUFFE
# 2   8,41087E+12                                 Fuettec
# 3   8,41255E+12                              Bienmesabe
# 4    8,4102E+12                    Quinoa blanca y roja
# ..          ...                                     ...
# 95  66701001029                          Cristal léger
# 96   7,6148E+12                 Toblerone chocolat noir
# 97  76183000410                        100% whole wheat
# 98     20203160                            Oriental Mix
# 99  7,47479E+11                Boisson  la Noix de coco
#
#                                         Category Healthy / Unhealthy  \
# 0                                        Alcohol           Unhealthy
# 1                                        Alcohol           Unhealthy
# 2                                        Alcohol           Unhealthy
# ...

# %%
# Counting the number of Beer products in USA and UK
beer_count_usa = foodhabits[(foodhabits['product_name'] == 'Beer')]

# Plotting
plt.bar(['USA'], [beer_count_usa], color=['blue'])
plt.xlabel('Countries')
plt.ylabel('Number of Beer Products')
plt.title('Distribution of Beer Products in USA and UK')
plt.tight_layout()

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 5>()
#       2 beer_count_usa = foodhabits[(foodhabits['product_name'] == 'Beer')]
#       4 # Plotting
# ----> 5 plt.bar(['USA'], [beer_count_usa], color=['blue'])
#       6 plt.xlabel('Countries')
#       7 plt.ylabel('Number of Beer Products')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2387, in bar(x, height, width, bottom, align, data, **kwargs)
#    2383 @_copy_docstring_and_deprecators(Axes.bar)
#    2384 def bar(
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
#    2389         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
